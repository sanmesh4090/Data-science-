# %%
name="Sanmesh"
city="Pune"
line="I am from"

# %%
print(line,city)
# Out:
# I am from Pune

# %%
names=["Sanmesh","Rohit","Sagar"]

# %%
print(names)
# Out:
# ('sam', 'aniket', 'saurabh')

# %%
print(type(names))
# Out:
# <class 'tuple'>

# %%
hight=6.8

# %%
print(hight)
# Out:
# 6.8

# %%
print(type(hight))
# Out:
# <class 'float'>

# %%
names={"Sanmesh","Rohit","Sagar"}
print(names)
print(type(names))
# Out:
# {'Rohit', 'Sagar', 'Sanmesh'}
# <class 'set'>

# %%
name="Sanmesh"
print(name)
print(type(name))
# Out:
# Sanmesh
# <class 'str'>

# %%
a = ("mango", "banana") # tuple

# %%
a = ["mango","banana"] # list

# %%
print(a)
# Out:
# ['mango', 'banana']

# %%
name = "ajay"

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
#create variable
a=10
b="sam"

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=10
name="sam"
sunny=True  #bol
rainy=False #bol

print(type(age))
print(type(name))
print(type(sunny))
print(type(rainy))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %%
#tuple
a = ("mango", "banana") # tuple
print(a)

print(type(a))
# Out:
# ('mango', 'banana')
# <class 'tuple'>

# %%
a='10'
b=20

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
a=int(a)
a+b
# Out:
# 30

# %%
int()
str()
float()
# Out:
# 0.0

# %%
a=10

a=float(a)
print(a)
print("type of a is:", type(a))
# Out:
# 10.0
# type of a is: <class 'float'>

# %%
a=10
b=23.0
c=20
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
b=int(b)
print((type)(a))
print((type)(b))
print((type)(c))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
#create a variable with integer and conert in the float

a=10
a=float(a)
print(a)
# Out:
# 10.0

# %%
#create a variable with float and convert in the integer
a=10.6
a=int(a)
print(a)
# Out:
# 10

# %%
#create a varibales with str and convert in the float and then in the integer
a="20"
a=float(a)
a=int(a)
print(a)

a=int(a)
print(a)
# Out:
# 20
# 20

# %%
#create a self bio using variables
name="Sanmesh"
city="kolhapur"
hobbies="videography,photography,travelling,gaming"
collage="DYPCET"
sports="cricket,football,cycling,kabaddi"
python="Python.python is a high-level, interpreted programming language. that is widely used for web development, data analysis, artificial intelligence, scientific computing, and more. "

print("My name is",name,"I am from",city,"I like",hobbies,"I am studying in",collage,"I like to play",sports,"I am learning",python)
# Out:
# My name is Sanmesh I am from kolhapur I like videography,photography,travelling,gaming I am studying in DYPCET I like to play cricket,football,cycling,kabaddi I am learning Python.python is a high-level, interpreted programming language. that is widely used for web development, data analysis, artificial intelligence, scientific computing, and more.

# %%
lyrics ="""twinkle twinkle little star
how I wonder what you are
up above the world so high
like a diamond in the sky
twinkle twinkle little star"""

print(lyrics)
# Out:
# twinkle twinkle little star
# how I wonder what you are
# up above the world so high
# like a diamond in the sky
# twinkle twinkle little star

# %%
cities = ["Pune", "Mumbai", "Delhi", "Bangalore", "Chennai"] #slices

cities[-3]
# Out:
# 'Delhi'

# %%
cities[3]
# Out:
# 'Bangalore'

# %%
cities[0:2]
# Out:
# ['Pune', 'Mumbai']

# %%
cities[2:5]
# Out:
# ['Delhi', 'Bangalore', 'Chennai']

# %%
cities[1:]
# Out:
# ['Mumbai', 'Delhi', 'Bangalore', 'Chennai']

# %%
cities[:4]
# Out:
# ['Pune', 'Mumbai', 'Delhi', 'Bangalore']

# %%
cities[-4:-1]
# Out:
# ['Mumbai', 'Delhi', 'Bangalore']

# %%
cities[::1]
# Out:
# ['Pune', 'Mumbai', 'Delhi', 'Bangalore', 'Chennai']
