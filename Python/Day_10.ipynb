# %% [markdown]
# ## Dictionary

# %%
student={"Name":"sam","Name":"raj"}

# %%
student
# Out:
# {'Name': 'raj'}

# %%
#Create a dictionary
student={"Name":"sam","Class":10,"City":"pune","Marks":[47,45,67]}

# %%
print(student)
# Out:
# {'Name': 'sam', 'Class': 10, 'City': 'pune', 'Marks': [47, 45, 67]}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Class', 'City', 'Marks'])

# %%
student={"Name":"sam","City":"Kolhapur","Hobbis":["videography","Photography","Sports"]}

# %%
student
# Out:
# {'Name': 'sam',
#  'City': 'Kolhapur',
#  'Hobbis': ['videography', 'Photography', 'Sports']}

# %% [markdown]
# # .keys()

# %%
student.keys() #keys
# Out:
# dict_keys(['Name', 'City', 'Hobbis'])

# %% [markdown]
# # .items()

# %%
student.items() #items
# Out:
# dict_items([('Name', 'sam'), ('City', 'Kolhapur'), ('Hobbis', ['videography', 'Photography', 'Sports'])])

# %% [markdown]
# # .values()

# %%
student.values() #Values
# Out:
# dict_values(['sam', 'Kolhapur', ['videography', 'Photography', 'Sports']])

# %%
student={"Name":"Sam",
         "Class":10,
         "Marks":[39,49,68],
         "id":101,
         "Sports":"cricket"}

# %%
student
# Out:
# {'Name': 'Sam',
#  'Class': 10,
#  'Marks': [39, 49, 68],
#  'id': 101,
#  'Sports': 'cricket'}

# %%
for key,values in student.items():
    print(key,"->",values)
# Out:
# Name -> Sam
# Class -> 10
# Marks -> [39, 49, 68]
# id -> 101
# Sports -> cricket

# %%
student["City"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 student["City"]
#
# KeyError: 'City'

# %% [markdown]
# # .get()

# %%
student.get("City") #get

# %%
for key,values in student.items():
    print(key,"->",values)
# Out:
# Name -> Sam
# Class -> 10
# Marks -> [39, 49, 68]
# id -> 101
# Sports -> cricket

# %%
student.get("id","key not present")
# Out:
# 101

# %%
student.get("city","key not present")
# Out:
# 'key not present'

# %% [markdown]
# # .update()

# %%
student.update({"id":1}) #Update

# %%
student.items()
# Out:
# dict_items([('Name', 'Sam'), ('Class', 10), ('Marks', [39, 49, 68]), ('id', 1), ('Sports', 'cricket')])

# %%
student.update({"Gender":"Male","Div":"A"})

# %%
student
# Out:
# {'Name': 'Sam',
#  'Class': 10,
#  'Marks': [39, 49, 68],
#  'id': 1,
#  'Sports': 'cricket',
#  'Gender': 'Male',
#  'Div': 'A'}

# %% [markdown]
# #  .pop()

# %%
student.pop("Marks")
# Out:
# [39, 49, 68]

# %%
student
# Out:
# {'Name': 'Sam',
#  'Class': 10,
#  'id': 1,
#  'Sports': 'cricket',
#  'Gender': 'Male',
#  'Div': 'A'}

# %%
student.pop("Div")
# Out:
# 'A'

# %%
student
# Out:
# {'Name': 'Sam', 'Class': 10, 'id': 1, 'Sports': 'cricket', 'Gender': 'Male'}

# %% [markdown]
# # .clear()

# %%
student.clear()

# %%
student
# Out:
# {}

# %% [markdown]
# # .copy()

# %%
a=student.copy()
print(a)
# Out:
# {'Name': 'Sam', 'Class': 10, 'Marks': [39, 49, 68], 'id': 101, 'Sports': 'cricket'}

# %%
b=a
print(b)
# Out:
# {'Name': 'Sam', 'Class': 10, 'Marks': [39, 49, 68], 'id': 101, 'Sports': 'cricket'}

# %%
#Create dictionary of student and marks
marks={
    "Sam":50,
    "Raj":56,
    "Aniket":89,
    "rohit":45,
    "Deeya":88
}

# %%
marks
# Out:
# {'Sam': 50, 'Raj': 56, 'Aniket': 89, 'rohit': 45, 'Deeya': 88}

# %%
for key,values in marks.items():
    print(key,"->",values)
# Out:
# Sam -> 50
# Raj -> 56
# Aniket -> 89
# rohit -> 45
# Deeya -> 88

# %%
for key,values in marks.items():
    if values>=50:
       print(key,"->",values)
# Out:
# Sam -> 50
# Raj -> 56
# Aniket -> 89
# Deeya -> 88
