# %% [markdown]
# # Functions

# %%
# Addition of two element
a=10
b=30
c=a+b
print(c)

# %%
def greet():
    print("Good morning")

# %%
greet()
# Out:
# Good morning

# %%
def greet(student_name):
    print("Good afternoon",student_name)

# %%
greet("sanmesh")
# Out:
# Good afternoon sanmesh

# %%
def Addition(a,b):
    print("Addition is:",a+b)

# %%
Addition(10,20)
# Out:
# Addition is: 30

# %%
def Add(y,z):
    print("Addition is:",y+z)

Add(100,230)
# Out:
# Addition is: 330

# %%
#Write a function for 3 element
def Add(a,b,c):
    print("Addition is ",a+b+c)

Add(20,10,39)
# Out:
# Addition is  69

# %%
#multiply the two element
def Mul(a,b):
    print("Multiplication is :",a*b)

Mul(20,10)
# Out:
# Multiplication is : 200

# %%
a=20
b=38

# %%
Mul(a,b)
# Out:
# Multiplication is : 760

# %% [markdown]
# # use return

# %%
def add(a,b):
    return a+b #return

result=add(20,40)

# %%
result
# Out:
# 60

# %%
#write a function for 2 element and store in result
def Mul(a,b):
    return a*b

result=Mul(29,10)

# %%
result
# Out:
# 290

# %%
#write a function for odd and even
def check(num):
    if num %2==0:
        print("Even")
    else:
        print("Odd")


check(2)
# Out:
# Even

# %%
check(1)
# Out:
# Odd

# %%
#percentage
marks=[66,77,88,99,100]

# %%
def per(marks):
    return sum(marks)/len(marks)

# %%
per(marks)
# Out:
# 86.0

# %%
carts=[26,80,56,156]

# %%
def avg(carts):
    return sum(carts)/len(carts)

# %%
avg(carts)
# Out:
# 79.5

# %%
def avg(carts):
    if len(carts)==0:
       return "Add value in cart"
    return sum(carts)/len(carts)

# %%
avg([20,10,20])
# Out:
# 16.666666666666668

# %%
#write any function for list to append -3 -4
#write a function to sort the list
#write a function for to check if value data contains duplicate or not[1,2,2,3]-True  [1,2,3,4]-false
