# %%
#Operators
##1 Arithmetic Operators
###Addition (+)
a=10
b=20
a+b
# Out:
# 30

# %%
#subtraction (-)
a=20
b=12
a-b
# Out:
# 8

# %%
#Division (/)
a=20
b=10
a/b
# Out:
# 2.0

# %%
#Floor Division (//)
a=20
b=11
a//b
# Out:
# 1

# %%
#Modulus (%)
a=20
b=8
a%b
# Out:
# 4

# %%
#Multiplication (*)
a=20
b=5
a*b
# Out:
# 100

# %%
#Exponentiation (**)
a=30
b=24
a**b
# Out:
# 282429536481000000000000000000000000

# %%
#Logical Operators
##and,or,not

(10>5) and (10<20) #all conditions are true then it will return true otherwise false
# Out:
# True

# %%
(10>5) or (10<20) #one condition is true then it will return true otherwise false
# Out:
# True

# %%
city=["Pune","mumbai","Delhi"] 

"delhi" not in city
# Out:
# True

# %%
#
#+=,-=,==
mark=60

# %%
mark=mark+10
mark
# Out:
# 80

# %%
mark+=10
mark
# Out:
# 100

# %%
mark-=10
mark
# Out:
# 90

# %%
#Comparison Operators
##=,==,!=,>,<,>=,<=
a=10 #equal to
b=20

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a<=b
# Out:
# True
