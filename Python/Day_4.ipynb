# %% [markdown]
# # Conditions
# # if else statement

# %%
age=20
if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %%
age=20
if age >=int(input("Enter your age: ")):
    print("You are an adult.")

else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
#Green:go,red:stop
signal = input("Enter green or red: ")
if signal == "green":
    print("Go")
else:
    print("Stop")
# Out:
# Stop

# %%
#Weekend:movie,weekday:work/study
day=str(input("Enter the day: "))
if day=="saturday" or day=="sunday":
    print("Movie")
else:
    print("Work/Study")
# Out:
# Work/Study

# %%
#hot/cold
temp=int(input("Enter the temperature: "))
if temp>10:
    print("Hot")

else:
    print("cold")
# Out:
# cold

# %%
#Fever/not fever
temp=int(input("enter the temperature: "))

if temp>100:
    print("you have fever")

else:
    print("you don't have fever")
# Out:
# you have fever

# %%
day=int(input())
if day==1:
    print("Monday")

elif day==2:
    print("Tuesday")

elif day==3:
    print("wednesday")

elif day==4:
    print("Thursday")

elif day==5:
    print("Friday")

elif day==6:
    print("Saturday")

elif day==7:
    print("sunday")

else:
    print("enter invalid day")
# Out:
# Thursday

# %%
signal=input()

if signal=="green":
    print("go")

elif signal=="red":
    print("stop")

else:
    print("alert,signal may get change/signal is not working properly")
# Out:
# stop
