# %% [markdown]
# # Tuple:
# ## -imutable
# ## -ordered
# ## -no change

# %%
a=(1,2,3,4)
a
# Out:
# (1, 2, 3, 4)

# %%
first_name = "Sanmesh"
print(first_name)
# Out:
# Sanmesh

# %%
shop=("mini","bata","puma")
print(shop)
# Out:
# ('mini', 'bata', 'puma')

# %%
shop[1:]
# Out:
# ('bata', 'puma')

# %%
shop[0]
# Out:
# 'mini'

# %%
shop[-1:]
# Out:
# ('puma',)

# %%
a=(1,2,3,4)
b=tuple(a)

# %%
b
# Out:
# (1, 2, 3, 4)

# %%
names=("Sanmesh","Rohit","Sagar","ram")

# %%
names="Sanmesh","Rohit","Sagar","ram"

# %%
names=[("Sanmesh","Rohit","Sagar","ram")]

# %%
names=tuple(("Sanmesh","Rohit","Sagar","ram"))

# %%
print("These are the names",names)
# Out:
# These are the names ('Sanmesh', 'Rohit', 'Sagar', 'ram')

# %%
print("The name is",names[0])
# Out:
# The name is Sanmesh

# %% [markdown]
# # Methods
# ## -index
# ## -count

# %%
party=("pizza","burger","pasta","soup","pizza")
party.count("pizza")
# Out:
# 2

# %%
party.count("soup")
# Out:
# 1

# %%
party.index("pasta")
# Out:
# 2

# %%
party[3]
# Out:
# 'soup'
