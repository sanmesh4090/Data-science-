# %% [markdown]
# # 2. while loop

# %%
i=5
while i<10:
    print(i)
    i+=1
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
cart=["apple","mango","peru","chiku"]

# %%
for i in cart:
    if i=="peru":
        print("we fount",i)
        break
    print(i)
# Out:
# apple
# mango
# we fount peru

# %%
marks=[32,26,45,65,34,12]

# %%
for i in marks:
    if i<=35:
        print(i,"failed")
    else:
        print(i,"you pass")
# Out:
# 32 failed
# 26 failed
# 45 you pass
# 65 you pass
# 34 failed
# 12 failed

# %%
apps=["insta","google","songs","zepto"]

# %%
for app in apps:
    print("checking app",app)   #break
    if app=="songs":
        print(app,"found")
        break
# Out:
# checking app insta
# checking app google
# checking app songs
# songs found

# %%
snaks=["chips","taco","burger","ban maska","oats","pizza"]

# %%
for i in snaks:
    if i=="oats":
        print("skip it please",i)
        continue
    print("yummy eating",i)
# Out:
# yummy eating chips
# yummy eating taco
# yummy eating burger
# yummy eating ban maska
# skip it please oats
# yummy eating pizza

# %%
marks=[39,40,36,59,40,76,23,56,86]

# %%
for i in marks:
    if i<70:
        print("you getting book",i)
    else:
        pass
# Out:
# you getting book 39
# you getting book 40
# you getting book 36
# you getting book 59
# you getting book 40
# you getting book 23
# you getting book 56

# %%
nums=[1,2,3,4,5]

# %%
for i in nums:
    if i== 3:
        pass
    else:
        print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
marks=[85,75,68,34,56]

# %%
for i in marks:
    if i<40:
        pass
    else:
        print("you pass exam",i)
# Out:
# you pass exam 85
# you pass exam 75
# you pass exam 68
# you pass exam 56
